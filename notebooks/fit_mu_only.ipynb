# %%
# Constants
import config.execution_parameters
from config.execution_parameters import *

# Project libraries
from src.simulator_package.simulator_functions import *
import src.hmm_package.generate_hmm
from src.hmm_package.generate_hmm import *
from src.plot_and_print_info.plots_and_print_info import *

import random
import importlib

# %%
importlib.reload(src.hmm_package.generate_hmm)
from src.hmm_package.generate_hmm import *
importlib.reload(config.execution_parameters)
from config.execution_parameters import *

# %%
empty_users = 5000
adstock_only_empty = tf.zeros([empty_users, N_states, execution_duration+1], dtype=float)
output_only_empty = np.zeros([empty_users, execution_duration+1])

# Lets add a 3% of conversion due to external factors
#for temp in range(round(0.03*empty_users)):
#    output_only_empty[temp, random.randint(1,execution_duration+1):] = 1
# Out:
# 2022-03-26 18:27:44.060938: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = build_hmm_to_fit_mu(states_observable=STATES_ARE_OBSERVABLE)

compiler = CompilerInfoMu(LR_EXPONENTIAL_DECAY)
model.compile(
    loss = compiler.loss,
    optimizer = compiler.optimizer,
    run_eagerly = True
)

fit_model(model, adstock_only_empty, output_only_empty)
# Out:
# Epoch 1/10000
# 2022-03-26 18:27:44.654390: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 20/20 [==============================] - 6s 309ms/step - loss: 1.3367
# Epoch 2/10000
# 20/20 [==============================] - 6s 305ms/step - loss: 1.3323
# Epoch 3/10000
# 20/20 [==============================] - 6s 301ms/step - loss: 1.3297
# Epoch 4/10000
# 20/20 [==============================] - 6s 302ms/step - loss: 1.3271
# Epoch 5/10000
# 20/20 [==============================] - 6s 302ms/step - loss: 1.3244
# Epoch 6/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 1.3218
# Epoch 7/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.3190
# Epoch 8/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.3163
# Epoch 9/10000
# 20/20 [==============================] - 6s 301ms/step - loss: 1.3135
# Epoch 10/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.3106
# Epoch 11/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.3077
# Epoch 12/10000
# 20/20 [==============================] - 6s 303ms/step - loss: 1.3048
# Epoch 13/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.3018
# Epoch 14/10000
# 20/20 [==============================] - 6s 301ms/step - loss: 1.2988
# Epoch 15/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.2957
# Epoch 16/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.2925
# Epoch 17/10000
# 20/20 [==============================] - 6s 304ms/step - loss: 1.2893
# Epoch 18/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.2861
# Epoch 19/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.2828
# Epoch 20/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.2794
# Epoch 21/10000
# 20/20 [==============================] - 6s 301ms/step - loss: 1.2760
# Epoch 22/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.2725
# Epoch 23/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 1.2690
# Epoch 24/10000
# 20/20 [==============================] - 6s 301ms/step - loss: 1.2654
# Epoch 25/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.2618
# Epoch 26/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.2581
# Epoch 27/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.2543
# Epoch 28/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.2504
# Epoch 29/10000
# 20/20 [==============================] - 6s 304ms/step - loss: 1.2465
# Epoch 30/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 1.2424
# Epoch 31/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.2383
# Epoch 32/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 1.2342
# Epoch 33/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 1.2299
# Epoch 34/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 1.2256
# Epoch 35/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 1.2225
# Epoch 36/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 1.2199
# Epoch 37/10000
# 20/20 [==============================] - 6s 304ms/step - loss: 1.2171
# Epoch 38/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.2142
# Epoch 39/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.2111
# Epoch 40/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.2077
# Epoch 41/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 1.2041
# Epoch 42/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 1.2002
# Epoch 43/10000
# 20/20 [==============================] - 6s 306ms/step - loss: 1.1960
# Epoch 44/10000
# 20/20 [==============================] - 7s 328ms/step - loss: 1.1916
# Epoch 45/10000
# 20/20 [==============================] - 7s 335ms/step - loss: 1.1868
# Epoch 46/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 1.1817
# Epoch 47/10000
# 20/20 [==============================] - 6s 303ms/step - loss: 1.1762
# Epoch 48/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 1.1704
# Epoch 49/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.1641
# Epoch 50/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 1.1575
# Epoch 51/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.1505
# Epoch 52/10000
# 20/20 [==============================] - 6s 324ms/step - loss: 1.1430
# Epoch 53/10000
# 20/20 [==============================] - 7s 333ms/step - loss: 1.1352
# Epoch 54/10000
# 20/20 [==============================] - 6s 303ms/step - loss: 1.1269
# Epoch 55/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.1183
# Epoch 56/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.1093
# Epoch 57/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.0999
# Epoch 58/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.0901
# Epoch 59/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.0800
# Epoch 60/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.0696
# Epoch 61/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 1.0589
# Epoch 62/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 1.0479
# Epoch 63/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.0368
# Epoch 64/10000
# 20/20 [==============================] - 6s 301ms/step - loss: 1.0254
# Epoch 65/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.0138
# Epoch 66/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 1.0021
# Epoch 67/10000
# 20/20 [==============================] - 6s 312ms/step - loss: 0.9903
# Epoch 68/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.9784
# Epoch 69/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.9665
# Epoch 70/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.9545
# Epoch 71/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.9425
# Epoch 72/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.9305
# Epoch 73/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.9186
# Epoch 74/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.9066
# Epoch 75/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.8948
# Epoch 76/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.8830
# Epoch 77/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.8713
# Epoch 78/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.8597
# Epoch 79/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.8483
# Epoch 80/10000
# 20/20 [==============================] - 6s 301ms/step - loss: 0.8370
# Epoch 81/10000
# 20/20 [==============================] - 6s 313ms/step - loss: 0.8258
# Epoch 82/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.8148
# Epoch 83/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.8040
# Epoch 84/10000
# 20/20 [==============================] - 6s 318ms/step - loss: 0.7933
# Epoch 85/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.7828
# Epoch 86/10000
# 20/20 [==============================] - 6s 312ms/step - loss: 0.7726
# Epoch 87/10000
# 20/20 [==============================] - 6s 302ms/step - loss: 0.7625
# Epoch 88/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.7526
# Epoch 89/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.7428
# Epoch 90/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.7333
# Epoch 91/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.7240
# Epoch 92/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.7149
# Epoch 93/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.7059
# Epoch 94/10000
# 20/20 [==============================] - 6s 303ms/step - loss: 0.6971
# Epoch 95/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.6886
# Epoch 96/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.6801
# Epoch 97/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 0.6719
# Epoch 98/10000
# 20/20 [==============================] - 6s 308ms/step - loss: 0.6638
# Epoch 99/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 0.6559
# Epoch 100/10000
# 20/20 [==============================] - 6s 296ms/step - loss: 0.6482
# Epoch 101/10000
# 20/20 [==============================] - 6s 296ms/step - loss: 0.6406
# Epoch 102/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 0.6331
# Epoch 103/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.6258
# Epoch 104/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.6186
# Epoch 105/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.6115
# Epoch 106/10000
# 20/20 [==============================] - 6s 301ms/step - loss: 0.6045
# Epoch 107/10000
# 20/20 [==============================] - 6s 303ms/step - loss: 0.5976
# Epoch 108/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.5909
# Epoch 109/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.5842
# Epoch 110/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.5777
# Epoch 111/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.5712
# Epoch 112/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.5648
# Epoch 113/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.5585
# Epoch 114/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.5525
# Epoch 115/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.5466
# Epoch 116/10000
# 20/20 [==============================] - 6s 300ms/step - loss: 0.5408
# Epoch 117/10000
# 20/20 [==============================] - 6s 306ms/step - loss: 0.5352
# Epoch 118/10000
# 20/20 [==============================] - 6s 298ms/step - loss: 0.5297
# Epoch 119/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 0.5242
# Epoch 120/10000
# 20/20 [==============================] - 6s 296ms/step - loss: 0.5189
# Epoch 121/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 0
10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5052
# Epoch 475/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5065
# Epoch 476/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5079
# Epoch 477/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5093
# Epoch 478/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5106
# Epoch 479/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5119
# Epoch 480/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5133
# Epoch 481/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5146
# Epoch 482/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5159
# Epoch 483/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5172
# Epoch 484/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5184
# Epoch 485/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5197
# Epoch 486/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5210
# Epoch 487/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5222
# Epoch 488/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 0.5234
# Epoch 489/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5247
# Epoch 490/10000
# 20/20 [==============================] - 6s 289ms/step - loss: 0.5259
# Epoch 491/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5271
# Epoch 492/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5283
# Epoch 493/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5294
# Epoch 494/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5306
# Epoch 495/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5318
# Epoch 496/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5329
# Epoch 497/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5341
# Epoch 498/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5352
# Epoch 499/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5363
# Epoch 500/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5374
# Epoch 501/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5385
# Epoch 502/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5396
# Epoch 503/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5407
# Epoch 504/10000
# 20/20 [==============================] - 6s 294ms/step - loss: 0.5418
# Epoch 505/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5429
# Epoch 506/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5439
# Epoch 507/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5450
# Epoch 508/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5460
# Epoch 509/10000
# 20/20 [==============================] - 6s 293ms/step - loss: 0.5470
# Epoch 510/10000
# 20/20 [==============================] - 6s 295ms/step - loss: 0.5480
# Epoch 511/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5491
# Epoch 512/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5501
# Epoch 513/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5511
# Epoch 514/10000
# 20/20 [==============================] - 6s 293ms/step - loss: 0.5520
# Epoch 515/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5530
# Epoch 516/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5540
# Epoch 517/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5549
# Epoch 518/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5559
# Epoch 519/10000
# 20/20 [==============================] - 6s 299ms/step - loss: 0.5568
# Epoch 520/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5578
# Epoch 521/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5587
# Epoch 522/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5596
# Epoch 523/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5605
# Epoch 524/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5615
# Epoch 525/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5623
# Epoch 526/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5632
# Epoch 527/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5641
# Epoch 528/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5650
# Epoch 529/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5659
# Epoch 530/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5667
# Epoch 531/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5676
# Epoch 532/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5684
# Epoch 533/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5693
# Epoch 534/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5701
# Epoch 535/10000
# 20/20 [==============================] - 6s 293ms/step - loss: 0.5709
# Epoch 536/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5717
# Epoch 537/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5725
# Epoch 538/10000
# 20/20 [==============================] - 6s 297ms/step - loss: 0.5733
# Epoch 539/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5741
# Epoch 540/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5749
# Epoch 541/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5757
# Epoch 542/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5765
# Epoch 543/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5773
# Epoch 544/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5780
# Epoch 545/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5788
# Epoch 546/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5795
# Epoch 547/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5803
# Epoch 548/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5810
# Epoch 549/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5817
# Epoch 550/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5823
# Epoch 551/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5829
# Epoch 552/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5835
# Epoch 553/10000
# 20/20 [==============================] - 6s 295ms/step - loss: 0.5841
# Epoch 554/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5847
# Epoch 555/10000
# 20/20 [==============================] - 6s 290ms/step - loss: 0.5852
# Epoch 556/10000
# 20/20 [==============================] - 6s 291ms/step - loss: 0.5858
# Epoch 557/10000
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5864
# Epoch 558/10000
# ...
#     221       inputs, *args, **kwargs)
#     222   self._enter_dunder_call = False
#     223   return distribution
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/keras/engine/base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    1092   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object):
# -> 1096   outputs = call_fn(inputs, *args, **kwargs)
#    1098 if self._activity_regularizer:
#    1099   self._handle_activity_regularization(inputs, outputs)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/keras/utils/traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow_probability/python/layers/distribution_layer.py:226, in DistributionLambda.call(self, inputs, *args, **kwargs)
#     225 def call(self, inputs, *args, **kwargs):
# --> 226   distribution, value = super(DistributionLambda, self).call(
#     227       inputs, *args, **kwargs)
#     228   # We always save the most recently built distribution variables for tracking
#     229   # purposes.
#     230   self._most_recently_built_distribution_vars = distribution.variables
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/keras/layers/core/lambda_layer.py:196, in Lambda.call(self, inputs, mask, training)
#     192   return var
#     194 with tf.GradientTape(watch_accessed_variables=True) as tape,\
#     195     tf.variable_creator_scope(_variable_creator):
# --> 196   result = self.function(inputs, **kwargs)
#     197 self._check_variables(created_variables, tape.watched_variables())
#     198 return result
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow_probability/python/layers/distribution_layer.py:180, in DistributionLambda.__init__.<locals>._fn(*fargs, **fkwargs)
#     171 distribution = dtc._TensorCoercible(  # pylint: disable=protected-access
#     172     distribution=d,
#     173     convert_to_tensor_fn=maybe_composite_convert_to_tensor_fn)
#     175 # Calling `distrbution._value()` is equivalent to:
#     176 # from tensorflow.python.framework import ops
#     177 # value = ops.convert_to_tensor_or_composite(distribution)
#     178 # We'd prefer to call ops.convert_to_tensor_or_composite but do not,
#     179 # favoring our own non-public API over TF's.
# --> 180 value = distribution._value()  # pylint: disable=protected-access
#     182 # TODO(b/126056144): Remove silent handle once we identify how/why Keras
#     183 # is losing the distribution handle for activity_regularizer.
#     184 value._tfp_distribution = distribution  # pylint: disable=protected-access
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow_probability/python/layers/internal/distribution_tensor_coercible.py:213, in _TensorCoercible._value(self, dtype, name, as_ref)
#     204   raise NotImplementedError(
#     205       'Failed to convert object of type {} to Tensor. Contents: {}. '
#     206       'Call `distribution.set_tensor_conversion(lambda self: ...)` to '
#    (...)
#     209       ' results in `tf.convert_to_tensor(x)` being identical to '
#     210       '`x.mean()`.'.format(type(self), self))
#     211 with self._name_and_control_scope('value'):
#     212   self._concrete_value = (
# --> 213       self._convert_to_tensor_fn(self.tensor_distribution)
#     214       if callable(self._convert_to_tensor_fn)
#     215       else self._convert_to_tensor_fn)
#     216   if (not tf.is_tensor(self._concrete_value) and
#     217       not isinstance(self._concrete_value,
#     218                      composite_tensor.CompositeTensor)):
#     219     self._concrete_value = nest_util.convert_to_nested_tensor(  # pylint: disable=protected-access
#     220         self._concrete_value,
#     221         name=name or 'concrete_value',
#     222         dtype=dtype,
#     223         dtype_hint=self.tensor_distribution.dtype)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py:1234, in Distribution.sample(self, sample_shape, seed, name, **kwargs)
#    1219 """Generate samples of the specified shape.
#    1220
#    1221 Note that a call to `sample()` without arguments will generate a single
#    (...)
#    1231   samples: a `Tensor` with prepended dimensions `sample_shape`.
#    1232 """
#    1233 with self._name_and_control_scope(name):
# -> 1234   return self._call_sample_n(sample_shape, seed, **kwargs)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py:1211, in Distribution._call_sample_n(self, sample_shape, seed, **kwargs)
#    1207 sample_shape = ps.convert_to_shape_tensor(
#    1208     ps.cast(sample_shape, tf.int32), name='sample_shape')
#    1209 sample_shape, n = self._expand_sample_shape_to_vector(
#    1210     sample_shape, 'sample_shape')
# -> 1211 samples = self._sample_n(
#    1212     n, seed=seed() if callable(seed) else seed, **kwargs)
#    1213 samples = tf.nest.map_structure(
#    1214     lambda x: tf.reshape(x, ps.concat([sample_shape, ps.shape(x)[1:]], 0)),
#    1215     samples)
#    1216 return self._set_sample_static_shape(samples, sample_shape)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow_probability/python/distributions/hidden_markov_model.py:389, in HiddenMarkovModel._sample_n(self, n, seed)
#     384   multiples = ps.concat([[self.num_steps],
#     385                          ps.ones(ps.rank(init_state), tf.int32)],
#     386                         axis=0)
#     387   return tf.tile(init_state[tf.newaxis, ...], multiples)
# --> 389 hidden_states = ps.cond(
#     390     self._num_steps > 1,
#     391     _scan_multiple_steps,
#     392     _scan_one_step)
#     394 hidden_one_hot = tf.one_hot(hidden_states, num_states,
#     395                             dtype=self._observation_distribution.dtype)
#     396 # hidden_one_hot :: num_steps n batch_size num_states
#     397
#     398 # The observation distribution batch size might not match
#     399 # the required batch size so as with the initial and
#     400 # transition distributions we generate more samples and
#     401 # reshape.
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow_probability/python/internal/prefer_static.py:260, in cond(pred, true_fn, false_fn, name)
#     258 if pred_value is not None:
#     259   if pred_value:
# --> 260     return true_fn()
#     261   else:
#     262     return false_fn()
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow_probability/python/distributions/hidden_markov_model.py:376, in HiddenMarkovModel._sample_n.<locals>._scan_multiple_steps()
#     374 """Take multiple steps with tf.scan."""
#     375 step = ps.range(self._num_steps - 1, dtype=tf.int32)
# --> 376 hidden_states, _ = tf.scan(generate_step, step,
#     377                            initializer=(init_state, scan_seed))
#     379 # TODO(b/115618503): add/use prepend_initializer to tf.scan
#     380 return tf.concat([[init_state],
#     381                   hidden_states], axis=0)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:616, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     609           _PRINTED_WARNING[(func, arg_name)] = True
#     610         logging.warning(
#     611             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     612             'will be removed %s.\nInstructions for updating:\n%s',
#     613             _call_location(), decorator_utils.get_qualified_name(func),
#     614             func.__module__, arg_name, arg_value, 'in a future version'
#     615             if date is None else ('after %s' % date), instructions)
# --> 616 return func(*args, **kwargs)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/ops/functional_ops.py:805, in scan_v2(fn, elems, initializer, parallel_iterations, back_prop, swap_memory, infer_shape, reverse, name)
#     693 @tf_export("scan", v1=[])
#     694 @dispatch.add_dispatch_support
#     695 @deprecation.deprecated_arg_values(
#    (...)
#     711             reverse=False,
#     712             name=None):
#     713   """scan on the list of tensors unpacked from `elems` on dimension 0.
#     714
#     715   The simplest version of `scan` repeatedly applies the callable `fn` to a
#    (...)
#     803     ```
#     804   """
# --> 805   return scan(
#     806       fn=fn,
#     807       elems=elems,
#     808       initializer=initializer,
#     809       parallel_iterations=parallel_iterations,
#     810       back_prop=back_prop,
#     811       swap_memory=swap_memory,
#     812       infer_shape=infer_shape,
#     813       reverse=reverse,
#     814       name=name)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/ops/functional_ops.py:663, in scan(fn, elems, initializer, parallel_iterations, back_prop, swap_memory, infer_shape, reverse, name)
#     661   initial_i = i
#     662   condition = lambda i, _1, _2: i < n
# --> 663 _, _, r_a = control_flow_ops.while_loop(
#     664     condition,
#     665     compute, (initial_i, a_flat, accs_ta),
#     666     parallel_iterations=parallel_iterations,
#     667     back_prop=back_prop,
#     668     swap_memory=swap_memory,
#     669     maximum_iterations=n)
#     671 results_flat = [r.stack() for r in r_a]
#     673 n_static = tensor_shape.Dimension(
#     674     tensor_shape.dimension_value(
#     675         elems_flat[0].get_shape().with_rank_at_least(1)[0]))
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py:2795, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2792 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#    2793                                         list(loop_vars))
#    2794 while cond(*loop_vars):
# -> 2795   loop_vars = body(*loop_vars)
#    2796   if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2797     packed = True
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py:2786, in while_loop.<locals>.<lambda>(i, lv)
#    2783     loop_vars = (counter, loop_vars)
#    2784     cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#    2785         math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# -> 2786     body = lambda i, lv: (i + 1, orig_body(*lv))
#    2787   try_to_pack = False
#    2789 if executing_eagerly:
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/ops/functional_ops.py:650, in scan.<locals>.compute(i, a_flat, tas)
#     647 nest.assert_same_structure(elems if initializer is None else initializer,
#     648                            a_out)
#     649 flat_a_out = output_flatten(a_out)
# --> 650 tas = [ta.write(i, value) for (ta, value) in zip(tas, flat_a_out)]
#     651 if reverse:
#     652   next_i = i - 1
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/ops/functional_ops.py:650, in <listcomp>(.0)
#     647 nest.assert_same_structure(elems if initializer is None else initializer,
#     648                            a_out)
#     649 flat_a_out = output_flatten(a_out)
# --> 650 tas = [ta.write(i, value) for (ta, value) in zip(tas, flat_a_out)]
#     651 if reverse:
#     652   next_i = i - 1
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py:243, in should_use_result.<locals>.decorated.<locals>.wrapped(*args, **kwargs)
#     242 def wrapped(*args, **kwargs):
# --> 243   return _add_should_use_warning(fn(*args, **kwargs),
#     244                                  warn_in_eager=warn_in_eager,
#     245                                  error_in_function=error_in_function)
#
# File ~/Library/Caches/JetBrains/PyCharm2021.3/demo/PyCharmLearningProject/venv/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py:209, in _add_should_use_warning(x, error_in_function, warn_in_eager)
#     200   stack_frame = sys.exc_info()[2].tb_frame.f_back
#     202 tf_should_use_helper = _TFShouldUseHelper(
#     203     type_=type(x),
#     204     repr_=repr(x),
#     205     stack_frame=stack_frame,
#     206     error_in_function=error_in_function,
#     207     warn_in_eager=warn_in_eager)
# --> 209 return _get_wrapper(x, tf_should_use_helper)
#
# KeyboardInterrupt:

# %%
fit_model(model, adstock_only_empty, output_only_empty)

# %%
make_non_exposed_user_transtion_matrix(model.weights,adstock_only_empty)
